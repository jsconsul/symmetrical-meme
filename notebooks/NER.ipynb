# %%
import pandas as pd
import json

# %%
df = pd.read_csv('raw_texts.csv')

# %%
df.columns
# Out:
# Index(['raw_text'], dtype='object')

# %%
df.shape
# Out:
# (3166, 1)

# %%
df.head()
# Out:
#                                             raw_text
# 0                                                NaN
# 1  When faced with the departure of our Chief Pro...
# 2  Diabetes goes far beyond excessive sugar consu...
# 3  With #COP30 currently taking place in Brazil, ...
# 4  During his long career in many countries and d...
